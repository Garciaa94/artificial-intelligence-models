# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#///////////////////////
# cargamos los datos 
dataset = pd.read_csv('practica.csv')
X= dataset.iloc[:,:-1].values 
y= dataset.iloc[:,:-1].values
print(X)
# Out:
# [[30]
#  [28]
#  [32]
#  [25]
#  [25]
#  [25]
#  [22]
#  [24]
#  [35]
#  [40]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#///////////
y_pred = regressor.predict(X_test)

# %%
viz_train = plt
viz_train.scatter(X_train, y_train, color='red')
viz_train.plot(X_train, regressor.predict(X_train),color='blue')
viz_train.title('Salary VS Experience (training set)')
viz_train.xlabel('Tear of Experience')
viz_train.ylabel('Salary')
viz_train.show()

# %%
viz_train = plt
viz_train.scatter(X_test, y_test, color='red')
viz_train.plot(X_train, regressor.predict(X_train),color='blue')
viz_train.title('Salary VS Experience (training set)')
viz_train.xlabel('Tear of Experience')
viz_train.ylabel('Salary')
viz_train.show()

# %%
y_predict = regressor.predict([[5]])
print("Predicction: ", y_predict)
# Out:
# Predicction:  [[5.]]

# %%
print('Precision del modelo: ')
print(regressor.score(X_train, y_train))
# Out:
# Precision del modelo:
# 1.0
