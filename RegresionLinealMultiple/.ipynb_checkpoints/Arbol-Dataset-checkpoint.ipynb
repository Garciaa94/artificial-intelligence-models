# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
from sklearn import tree
from sklearn import datasets
from sklearn.datasets import load_iris
iris=load_iris()

# %%
x_entrenamiento,x_test,y_entrenamiento,y_test=train_test_split(iris.data,iris.target,test_size=0.2)

# %%
arbol= tree.DecisionTreeClassifier()

# %%
arbol.fit(x_entrenamiento,y_entrenamiento)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = arbol.predict(x_test)
arbol.score(x_test,y_pred)
print(y_test,y_pred)
# Out:
# [2 2 2 0 1 2 1 2 0 2 1 0 1 2 2 2 2 0 2 1 1 0 1 2 1 1 2 1 2 1] [1 2 1 0 1 2 1 2 0 2 1 0 1 2 2 2 2 0 2 1 1 0 2 2 1 1 1 1 2 1]

# %%
with open("iris_tree.dot",'w') as archivo_dot:
    tree.export_graphviz(arbol,out_file=archivo_dot)

# %%
y_one=arbol.predict([[4,2,3,1]])
print(y_one)
# Out:
# [1]
